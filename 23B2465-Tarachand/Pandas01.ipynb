# %%
# Question 5: Start
# import pandas library

import pandas as pd

# %%
# Copy your path and store in the below variable.
# Note that the path will be a string

# Uncomment the below line

path = "/content/drive/MyDrive/Colab Notebooks/iris.csv"


# Load the dataframe

df = pd.read_csv(path)

# %%
# Print out the first 7 rows using head()

print(df.head(7))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
# Print out the last 10 rows

print(df.tail(10))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# How many rows and columns are there in this dataset

print(df.shape)

#OR

print("Number of rows : " , df.shape[0])
print("Number of columns : " , df.shape[1])
# Out:
# (150, 5)
# Number of rows :  150
# Number of columns :  5

# %%
# Print the info of this dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Check if the dataset has null values

df.isnull()

#OR

df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# From the describe method what is std (standard deviation) of petal_width

#stdfile = df.describe()
print(stdfile["petal_width"]["std"])

#OR

print("Standard deviation of sepal_length is : " , df["sepal_length"].std())
# Out:
# 0.7631607417008411
# Standard deviation of sepal_length is :  0.828066127977863

# %%
# Print out all the names of the column using a predifined method
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#How many types of values are there in species column

df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# Select all rows whose species column value is setosa
# Print out the shape of this dataframe

Setosa = df[df["species"] == "setosa"]
Setosa.shape
# Out:
# (50, 5)

# %%
# Select all rows whose species column value is virginica
# Print out the shape of this dataframe

Virginica = df[df["species"] == "virginica"]

Virginica.shape
# Out:
# (50, 5)

# %%
# Make a new dataframe called "df_new" by concatenating the above dataframes
# Print out the shape of this dataframe

#new_df = df[df["species"] == "setosa"] + df[df["species"] == "virginica"]

#new_df = Virginica + Setosa
new_df = pd.concat([ Setosa , Virginica ] , axis = 0)
new_df.shape
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [100 rows x 5 columns]

# %%
new_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    100.000000   100.000000    100.000000   100.000000
# mean       5.797000     3.196000      3.508000     1.135000
# std        0.945319     0.416071      2.094229     0.919198
# min        4.300000     2.200000      1.000000     0.100000
# 25%        5.000000     3.000000      1.500000     0.200000
# 50%        5.700000     3.150000      3.200000     1.000000
# 75%        6.500000     3.400000      5.525000     2.000000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Print the average sepal_length of these two species

new_df.groupby("species")["sepal_length"].mean()
# Out:
# species
# setosa       5.006
# virginica    6.588
# Name: sepal_length, dtype: float64

# %%
# Create a new column called "sepal_area" which is computed by taking the product of sepal_length and sepal_width
# Print the min and max area

df["sepal_area"] = df["sepal_length"] * df["sepal_width"]

print("Print min sepal_area : ",df["sepal_area"].min())
print("Print max sepal_area : ",df["sepal_area"].max())
#df["sepal_area"]
# Out:
# Print min sepal_area :  10.0
# Print max sepal_area :  30.02

# %%
# Print out all the names of the columns using predefined method

df.columns
# Out:
# Index([    'sepal_length',      'sepal_width',     'petal_length',
#             'petal_width',          'species', 17.849999999999998,
#        14.700000000000001, 15.040000000000001,              14.26,
#                      18.0,
#        ...
#                      21.6,              20.72,              30.02,
#        17.639999999999997,              15.86, 21.419999999999998,
#        19.840000000000003,              21.76,              21.08,
#              'sepal_area'],
#       dtype='object', length=115)

# %%
# From the above output copy all the names except petal_length and store it in a list

columns = ['sepal_length',      'sepal_width',
            'petal_width', 'sepal_area']

# %%
# From the above list create a new dataframe "df_new2" from df_new which have only the columns mentioned in the list
# Print out the shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-e8b7a0591451> in <cell line: 4>()
#       2 # Print out the shape
#       3
# ----> 4 df_new2 = new_df[columns]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941             raise KeyError(f"{not_found} not in index")
#    5942
#    5943     @overload
#
# KeyError: "['sepal_area'] not in index"

# %%
# Swap setosa with 1
# Swap virginica with 0
# Do this using replace()
